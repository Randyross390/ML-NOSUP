# %% [markdown]
# ## Unsupervised Learning
# #### by **Ivan Alducin**
# <p><img src="https://cdn.gritglobal.io/uploads/too-broad-customer-segmentation.jpg" width="1000"/></p>

# %% [markdown]
# ## Segmentacion de Clientes
# <p>En esté capitulo nos vamos a enfocar en entender y trabajar un caso de uso para segmentación de clientes, pero antes de eso aquí una pequeña lista de más aplicaciones que se pueden trabajar con los datos recopliados de mis clientes
#
# - Estadística Descriptiva
# - Segmentación de Clientes
# - Predicción de Abandono
# - Valor del Cliente a traves del tiempo (CTLV)
#
# La segmentación la vamos a hacer con base en una metodolgía llamada <b>RFM</b>
#
# </p>

# %%
# Importa Pandas, Numpy, Seaborn y Matplotlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# Importa el archivo "Online Retail.csv"
dire = r"C:\Users\randy\OneDrive\Escritorio\DataScience_Workspace\data\Bases.docs\M30 Online Retail.csv"
data = pd.read_csv(dire, encoding='latin-1', low_memory=False)

# %%
data
# Out:
#        INVOICE_NO STOCK_CODE                          DESCRIPTION  QUANTITY  \
# 0          536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365      71053                  WHITE METAL LANTERN         6
# 2          536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...        ...                                  ...       ...
# 541904     581587      22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587      22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             INVOICE_DATE  UNIT_PRICE  CUSTOMER_ID          REGION
# 0       01/12/2019 08:26        2.55      17850.0  United Kingdom
# 1       01/12/2019 08:26        3.39      17850.0  United Kingdom
# 2       01/12/2019 08:26        2.75      17850.0  United Kingdom
# 3       01/12/2019 08:26        3.39      17850.0  United Kingdom
# 4       01/12/2019 08:26        3.39      17850.0  United Kingdom
# ...                  ...         ...          ...             ...
# 541904  09/12/2020 12:50        0.85      12680.0          France
# 541905  09/12/2020 12:50        2.10      12680.0          France
# 541906  09/12/2020 12:50        4.15      12680.0          France
# 541907  09/12/2020 12:50        4.15      12680.0          France
# 541908  09/12/2020 12:50        4.95      12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# # EDA

# %%
# Análisis Exploratorio
print("=" * 80)
print("1. INFORMACIÓN GENERAL DEL DATASET")
print("=" * 80)
print(f"Dimensiones: {data.shape[0]} filas x {data.shape[1]} columnas")
print(f"\nColumnas del dataset:")
print(data.columns.tolist())
print(f"\nPrimeras 10 filas:")
print(data.head(10))

print("\n" + "=" * 80)
print("2. TIPOS DE DATOS Y VALORES NULOS")
print("=" * 80)
print(data.info())
print(f"\n{'Columna':<20} {'Nulos':<10} {'% Nulos':<10}")
print("-" * 40)
for col in data.columns:
    nulos = data[col].isnull().sum()
    porcentaje = (nulos / len(data) * 100)
    print(f"{col:<20} {nulos:<10} {porcentaje:<10.2f}%")

print("3. ESTADÍSTICAS DESCRIPTIVAS - VARIABLES NUMÉRICAS")
print("=" * 80)
print(data.describe())

print("\n" + "=" * 80)
print("4. ANÁLISIS DE VALORES ÚNICOS POR COLUMNA")
print("=" * 80)
print(f"{'Columna':<20} {'Valores Únicos':<20} {'Tipo de Dato':<20}")
print("-" * 60)
for col in data.columns:
    print(f"{col:<20} {data[col].nunique():<20} {str(data[col].dtype):<20}")


print("5. REGISTROS DUPLICADOS")
print("=" * 80)
duplicados = data.duplicated().sum()
print(f"Total de registros duplicados: {duplicados:,}")
print(f"Porcentaje de duplicados: {(duplicados/len(data)*100):.2f}%")
if duplicados > 0:
    print(f"\nEjemplo de registros duplicados:")
    print(data[data.duplicated(keep=False)].head())

print("6. ANÁLISIS DE INVOICE_NO (FACTURAS)")
print("=" * 80)
print(f"Total de facturas únicas: {data['INVOICE_NO'].nunique():,}")
print(f"Total de transacciones: {len(data):,}")
print(f"Promedio de ítems por factura: {len(data) / data['INVOICE_NO'].nunique():.2f}")
print(f"\nTop 10 facturas con más ítems:")
print(data['INVOICE_NO'].value_counts().head(10))

print("7. ANÁLISIS DE QUANTITY (CANTIDAD)")
print("=" * 80)
print(f"Estadísticas de Quantity:")
print(data['QUANTITY'].describe())
print(f"\nDistribución de valores:")
print(f"  - Valores negativos (devoluciones): {(data['QUANTITY'] < 0).sum():,} ({(data['QUANTITY'] < 0).sum()/len(data)*100:.2f}%)")
print(f"  - Valores cero: {(data['QUANTITY'] == 0).sum():,}")
print(f"  - Valores positivos: {(data['QUANTITY'] > 0).sum():,} ({(data['QUANTITY'] > 0).sum()/len(data)*100:.2f}%)")
print(f"\nCantidad máxima en una transacción: {data['QUANTITY'].max():,}")
print(f"Cantidad mínima (devolución más grande): {data['QUANTITY'].min():,}")


print("8. ANÁLISIS DE UNIT_PRICE (PRECIO UNITARIO)")
print("=" * 80)
print(f"Estadísticas de Unit Price:")
print(data['UNIT_PRICE'].describe())
print(f"\nAnálisis de precios:")
print(f"  - Precios = 0: {(data['UNIT_PRICE'] == 0).sum():,}")
print(f"  - Precios negativos: {(data['UNIT_PRICE'] < 0).sum():,}")
print(f"  - Precios válidos (>0): {(data['UNIT_PRICE'] > 0).sum():,}")
print(f"\nPrecio máximo: ${data['UNIT_PRICE'].max():,.2f}")
print(f"Precio promedio: ${data['UNIT_PRICE'].mean():.2f}")
print(f"Precio mediano: ${data['UNIT_PRICE'].median():.2f}")


print("9. ANÁLISIS DE CUSTOMER_ID (CLIENTES)")
print("=" * 80)
clientes_nulos = data['CUSTOMER_ID'].isnull().sum()
clientes_unicos = data['CUSTOMER_ID'].nunique()
print(f"Total de clientes únicos: {clientes_unicos:,}")
print(f"Transacciones sin Customer ID: {clientes_nulos:,} ({clientes_nulos/len(data)*100:.2f}%)")
print(f"Transacciones con Customer ID: {(len(data) - clientes_nulos):,}")

if clientes_nulos < len(data):
    data_con_cliente = data[data['CUSTOMER_ID'].notna()]
    print(f"\nPromedio de transacciones por cliente: {len(data_con_cliente) / clientes_unicos:.2f}")
    print(f"\nTop 10 clientes con más transacciones:")
    top_clientes = data_con_cliente['CUSTOMER_ID'].value_counts().head(10)
    for idx, (cliente, transacciones) in enumerate(top_clientes.items(), 1):
        print(f"  {idx}. Cliente {int(cliente)}: {transacciones:,} transacciones")


print("10. ANÁLISIS DE STOCK_CODE Y DESCRIPTION (PRODUCTOS)")
print("=" * 80)
productos_unicos = data['STOCK_CODE'].nunique()
print(f"Total de productos únicos (Stock Code): {productos_unicos:,}")
print(f"Descripciones únicas: {data['DESCRIPTION'].nunique():,}")
print(f"Productos sin descripción: {data['DESCRIPTION'].isnull().sum():,}")

print(f"\nTop 10 productos más vendidos (por cantidad de transacciones):")
top_productos = data['STOCK_CODE'].value_counts().head(10)
for idx, (codigo, cantidad) in enumerate(top_productos.items(), 1):
    desc = data[data['STOCK_CODE'] == codigo]['DESCRIPTION'].mode()
    desc_text = desc.values[0] if len(desc) > 0 else "Sin descripción"
    print(f"  {idx}. {codigo}: {cantidad:,} transacciones - {desc_text}")

print("11. ANÁLISIS DE INVOICE_DATE (FECHAS)")
print("=" * 80)
# Intentar convertir a datetime
try:
    data['INVOICE_DATE'] = pd.to_datetime(data['INVOICE_DATE'])
    print(f"Rango de fechas:")
    print(f"  - Fecha más antigua: {data['INVOICE_DATE'].min()}")
    print(f"  - Fecha más reciente: {data['INVOICE_DATE'].max()}")
    print(f"  - Período total: {(data['INVOICE_DATE'].max() - data['INVOICE_DATE'].min()).days} días")
    
    # Análisis por mes
    data['Mes'] = data['INVOICE_DATE'].dt.to_period('M')
    print(f"\nTransacciones por mes:")
    print(data['Mes'].value_counts().sort_index().head(10))
except:
    print("No se pudo convertir INVOICE_DATE a formato datetime")
    print(f"Primeras fechas del dataset:")
    print(data['INVOICE_DATE'].head(10))

print("\n" + "=" * 80)
print("12. ANÁLISIS DE REGION (DISTRIBUCIÓN GEOGRÁFICA)")
print("=" * 80)
if 'REGION' in data.columns:
    regiones_unicas = data['REGION'].nunique()
    print(f"Total de regiones: {regiones_unicas}")
    print(f"\nDistribución de transacciones por región:")
    region_counts = data['REGION'].value_counts()
    for region, count in region_counts.items():
        porcentaje = (count / len(data) * 100)
        print(f"  - {region}: {count:,} transacciones ({porcentaje:.2f}%)")
else:
    print("Columna REGION no encontrada en el dataset")

print("13. RESUMEN EJECUTIVO DE CALIDAD DE DATOS")
print("=" * 80)
print(f" DATOS GENERALES:")
print(f"  ✓ Total de registros: {len(data):,}")
print(f"  ✓ Total de columnas: {len(data.columns)}")
print(f"  ✓ Memoria utilizada: {data.memory_usage(deep=True).sum() / 1024**2:.2f} MB")

print(f"\n COMPLETITUD:")
registros_completos = data.dropna().shape[0]
print(f"  ✓ Registros completos (sin nulos): {registros_completos:,} ({registros_completos/len(data)*100:.2f}%)")
registros_con_nulos = data.isnull().any(axis=1).sum()
print(f"  ✓ Registros con al menos un nulo: {registros_con_nulos:,} ({registros_con_nulos/len(data)*100:.2f}%)")

print(f"\n DATOS DE NEGOCIO:")
print(f"  ✓ Facturas únicas: {data['INVOICE_NO'].nunique():,}")
print(f"  ✓ Clientes únicos: {data['CUSTOMER_ID'].nunique():,}")
print(f"  ✓ Productos únicos: {data['STOCK_CODE'].nunique():,}")

print("\n" + "=" * 80)
print("  RECOMENDACIONES PARA LIMPIEZA:")
print("=" * 80)
print("1. * Tratar {0:,} valores nulos en CUSTOMER_ID ({1:.1f}%)".format(
    data['CUSTOMER_ID'].isnull().sum(), 
    data['CUSTOMER_ID'].isnull().sum()/len(data)*100))
print("2. * Investigar {0:,} valores negativos en QUANTITY (posibles devoluciones)".format(
    (data['QUANTITY'] < 0).sum()))
print("3. * Verificar {0:,} precios <= 0 en UNIT_PRICE".format(
    (data['UNIT_PRICE'] <= 0).sum()))
print("4. ✓ Convertir INVOICE_DATE a formato datetime para análisis temporal")
print("5. ✓ Considerar crear variable de 'Monto Total' = QUANTITY * UNIT_PRICE")
if data['DESCRIPTION'].isnull().sum() > 0:
    print("6. * Tratar {0:,} descripciones faltantes en DESCRIPTION".format(
        data['DESCRIPTION'].isnull().sum()))
print("=" * 80)
# Out:
# ================================================================================
# 1. INFORMACIÓN GENERAL DEL DATASET
# ================================================================================
# Dimensiones: 541909 filas x 8 columnas
#
# Columnas del dataset:
# ['INVOICE_NO', 'STOCK_CODE', 'DESCRIPTION', 'QUANTITY', 'INVOICE_DATE', 'UNIT_PRICE', 'CUSTOMER_ID', 'REGION']
#
# Primeras 10 filas:
#   INVOICE_NO STOCK_CODE                          DESCRIPTION  QUANTITY  \
# 0     536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1     536365      71053                  WHITE METAL LANTERN         6
# 2     536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3     536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4     536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5     536365      22752         SET 7 BABUSHKA NESTING BOXES         2
# 6     536365      21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7     536366      22633               HAND WARMER UNION JACK         6
# 8     536366      22632            HAND WARMER RED POLKA DOT         6
# 9     536367      84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#        INVOICE_DATE  UNIT_PRICE  CUSTOMER_ID          REGION
# 0  01/12/2019 08:26        2.55      17850.0  United Kingdom
# 1  01/12/2019 08:26        3.39      17850.0  United Kingdom
# 2  01/12/2019 08:26        2.75      17850.0  United Kingdom
# 3  01/12/2019 08:26        3.39      17850.0  United Kingdom
# 4  01/12/2019 08:26        3.39      17850.0  United Kingdom
# 5  01/12/2019 08:26        7.65      17850.0  United Kingdom
# 6  01/12/2019 08:26        4.25      17850.0  United Kingdom
# 7  01/12/2019 08:28        1.85      17850.0  United Kingdom
# 8  01/12/2019 08:28        1.85      17850.0  United Kingdom
# 9  01/12/2019 08:34        1.69      13047.0  United Kingdom
#
# ================================================================================
# 2. TIPOS DE DATOS Y VALORES NULOS
# ================================================================================
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   INVOICE_NO    541909 non-null  object
#  1   STOCK_CODE    541909 non-null  object
#  2   DESCRIPTION   540455 non-null  object
#  3   QUANTITY      541909 non-null  int64
#  4   INVOICE_DATE  541909 non-null  object
#  5   UNIT_PRICE    541909 non-null  float64
#  6   CUSTOMER_ID   406829 non-null  float64
#  7   REGION        541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB
# None
#
# Columna              Nulos      % Nulos
# ----------------------------------------
# INVOICE_NO           0          0.00      %
# STOCK_CODE           0          0.00      %
# DESCRIPTION          1454       0.27      %
# QUANTITY             0          0.00      %
# INVOICE_DATE         0          0.00      %
# UNIT_PRICE           0          0.00      %
# CUSTOMER_ID          135080     24.93     %
# REGION               0          0.00      %
# 3. ESTADÍSTICAS DESCRIPTIVAS - VARIABLES NUMÉRICAS
# ================================================================================
#             QUANTITY     UNIT_PRICE    CUSTOMER_ID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000
#
# ================================================================================
# 4. ANÁLISIS DE VALORES ÚNICOS POR COLUMNA
# ================================================================================
# Columna              Valores Únicos       Tipo de Dato
# ------------------------------------------------------------
# INVOICE_NO           25900                object
# STOCK_CODE           4070                 object
# DESCRIPTION          4214                 object
# QUANTITY             722                  int64
# INVOICE_DATE         23260                object
# UNIT_PRICE           1630                 float64
# CUSTOMER_ID          4372                 float64
# REGION               38                   object
# 5. REGISTROS DUPLICADOS
# ================================================================================
# Total de registros duplicados: 5,268
# Porcentaje de duplicados: 0.97%
#
# Ejemplo de registros duplicados:
#     INVOICE_NO STOCK_CODE                       DESCRIPTION  QUANTITY  \
# 485     536409      22111      SCOTTIE DOG HOT WATER BOTTLE         1
# 489     536409      22866     HAND WARMER SCOTTY DOG DESIGN         1
# 494     536409      21866       UNION JACK FLAG LUGGAGE TAG         1
# 517     536409      21866       UNION JACK FLAG LUGGAGE TAG         1
# 521     536409      22900   SET 2 TEA TOWELS I LOVE LONDON          1
#
#          INVOICE_DATE  UNIT_PRICE  CUSTOMER_ID          REGION
# 485  01/12/2019 11:45        4.95      17908.0  United Kingdom
# 489  01/12/2019 11:45        2.10      17908.0  United Kingdom
# 494  01/12/2019 11:45        1.25      17908.0  United Kingdom
# 517  01/12/2019 11:45        1.25      17908.0  United Kingdom
# 521  01/12/2019 11:45        2.95      17908.0  United Kingdom
# 6. ANÁLISIS DE INVOICE_NO (FACTURAS)
# ================================================================================
# Total de facturas únicas: 25,900
# Total de transacciones: 541,909
# Promedio de ítems por factura: 20.92
#
# Top 10 facturas con más ítems:
# INVOICE_NO
# 573585    1114
# 581219     749
# 581492     731
# 580729     721
# 558475     705
# 579777     687
# 581217     676
# 537434     675
# 580730     662
# 538071     652
# Name: count, dtype: int64
# 7. ANÁLISIS DE QUANTITY (CANTIDAD)
# ================================================================================
# Estadísticas de Quantity:
# count    541909.000000
# mean          9.552250
# std         218.081158
# min      -80995.000000
# 25%           1.000000
# 50%           3.000000
# 75%          10.000000
# max       80995.000000
# Name: QUANTITY, dtype: float64
#
# Distribución de valores:
#   - Valores negativos (devoluciones): 10,624 (1.96%)
#   - Valores cero: 0
#   - Valores positivos: 531,285 (98.04%)
#
# Cantidad máxima en una transacción: 80,995
# Cantidad mínima (devolución más grande): -80,995
# 8. ANÁLISIS DE UNIT_PRICE (PRECIO UNITARIO)
# ================================================================================
# Estadísticas de Unit Price:
# count    541909.000000
# mean          4.611114
# std          96.759853
# min      -11062.060000
# 25%           1.250000
# 50%           2.080000
# 75%           4.130000
# max       38970.000000
# Name: UNIT_PRICE, dtype: float64
#
# Análisis de precios:
#   - Precios = 0: 2,515
#   - Precios negativos: 2
#   - Precios válidos (>0): 539,392
#
# Precio máximo: $38,970.00
# Precio promedio: $4.61
# Precio mediano: $2.08
# 9. ANÁLISIS DE CUSTOMER_ID (CLIENTES)
# ================================================================================
# Total de clientes únicos: 4,372
# Transacciones sin Customer ID: 135,080 (24.93%)
# Transacciones con Customer ID: 406,829
#
# Promedio de transacciones por cliente: 93.05
#
# Top 10 clientes con más transacciones:
#   1. Cliente 17841: 7,983 transacciones
#   2. Cliente 14911: 5,903 transacciones
#   3. Cliente 14096: 5,128 transacciones
#   4. Cliente 12748: 4,642 transacciones
#   5. Cliente 14606: 2,782 transacciones
#   6. Cliente 15311: 2,491 transacciones
#   7. Cliente 14646: 2,085 transacciones
#   8. Cliente 13089: 1,857 transacciones
#   9. Cliente 13263: 1,677 transacciones
#   10. Cliente 14298: 1,640 transacciones
# 10. ANÁLISIS DE STOCK_CODE Y DESCRIPTION (PRODUCTOS)
# ================================================================================
# Total de productos únicos (Stock Code): 4,070
# Descripciones únicas: 4,214
# Productos sin descripción: 1,454
#
# Top 10 productos más vendidos (por cantidad de transacciones):
#   1. 85123A: 2,313 transacciones - WHITE HANGING HEART T-LIGHT HOLDER
#   2. 22423: 2,203 transacciones - REGENCY CAKESTAND 3 TIER
#   3. 85099B: 2,159 transacciones - JUMBO BAG RED RETROSPOT
#   4. 47566: 1,727 transacciones - PARTY BUNTING
#   5. 20725: 1,639 transacciones - LUNCH BAG RED RETROSPOT
#   6. 84879: 1,502 transacciones - ASSORTED COLOUR BIRD ORNAMENT
#   7. 22720: 1,477 transacciones - SET OF 3 CAKE TINS PANTRY DESIGN
#   8. 22197: 1,476 transacciones - POPCORN HOLDER
#   9. 21212: 1,385 transacciones - PACK OF 72 RETROSPOT CAKE CASES
#   10. 20727: 1,350 transacciones - LUNCH BAG  BLACK SKULL.
# 11. ANÁLISIS DE INVOICE_DATE (FECHAS)
# ================================================================================
# No se pudo convertir INVOICE_DATE a formato datetime
# Primeras fechas del dataset:
# 0    01/12/2019 08:26
# 1    01/12/2019 08:26
# 2    01/12/2019 08:26
# 3    01/12/2019 08:26
# 4    01/12/2019 08:26
# 5    01/12/2019 08:26
# 6    01/12/2019 08:26
# 7    01/12/2019 08:28
# 8    01/12/2019 08:28
# 9    01/12/2019 08:34
# Name: INVOICE_DATE, dtype: object
#
# ================================================================================
# 12. ANÁLISIS DE REGION (DISTRIBUCIÓN GEOGRÁFICA)
# ================================================================================
# Total de regiones: 38
#
# Distribución de transacciones por región:
#   - United Kingdom: 495,478 transacciones (91.43%)
#   - Germany: 9,495 transacciones (1.75%)
#   - France: 8,557 transacciones (1.58%)
#   - EIRE: 8,196 transacciones (1.51%)
#   - Spain: 2,533 transacciones (0.47%)
#   - Netherlands: 2,371 transacciones (0.44%)
#   - Belgium: 2,069 transacciones (0.38%)
#   - Switzerland: 2,002 transacciones (0.37%)
#   - Portugal: 1,519 transacciones (0.28%)
#   - Australia: 1,259 transacciones (0.23%)
#   - Norway: 1,086 transacciones (0.20%)
#   - Italy: 803 transacciones (0.15%)
#   - Channel Islands: 758 transacciones (0.14%)
#   - Finland: 695 transacciones (0.13%)
#   - Cyprus: 622 transacciones (0.11%)
#   - Sweden: 462 transacciones (0.09%)
#   - Unspecified: 446 transacciones (0.08%)
#   - Austria: 401 transacciones (0.07%)
#   - Denmark: 389 transacciones (0.07%)
#   - Japan: 358 transacciones (0.07%)
#   - Poland: 341 transacciones (0.06%)
#   - Israel: 297 transacciones (0.05%)
#   - USA: 291 transacciones (0.05%)
#   - Hong Kong: 288 transacciones (0.05%)
#   - Singapore: 229 transacciones (0.04%)
#   - Iceland: 182 transacciones (0.03%)
#   - Canada: 151 transacciones (0.03%)
#   - Greece: 146 transacciones (0.03%)
#   - Malta: 127 transacciones (0.02%)
#   - United Arab Emirates: 68 transacciones (0.01%)
#   - European Community: 61 transacciones (0.01%)
#   - RSA: 58 transacciones (0.01%)
#   - Lebanon: 45 transacciones (0.01%)
#   - Lithuania: 35 transacciones (0.01%)
#   - Brazil: 32 transacciones (0.01%)
#   - Czech Republic: 30 transacciones (0.01%)
#   - Bahrain: 19 transacciones (0.00%)
#   - Saudi Arabia: 10 transacciones (0.00%)
# 13. RESUMEN EJECUTIVO DE CALIDAD DE DATOS
# ================================================================================
#  DATOS GENERALES:
#   ✓ Total de registros: 541,909
#   ✓ Total de columnas: 8
#   ✓ Memoria utilizada: 173.64 MB
#
#  COMPLETITUD:
#   ✓ Registros completos (sin nulos): 406,829 (75.07%)
#   ✓ Registros con al menos un nulo: 135,080 (24.93%)
#
#  DATOS DE NEGOCIO:
#   ✓ Facturas únicas: 25,900
#   ✓ Clientes únicos: 4,372
#   ✓ Productos únicos: 4,070
#
# ================================================================================
#   RECOMENDACIONES PARA LIMPIEZA:
# ================================================================================
# 1. * Tratar 135,080 valores nulos en CUSTOMER_ID (24.9%)
# 2. * Investigar 10,624 valores negativos en QUANTITY (posibles devoluciones)
# 3. * Verificar 2,517 precios <= 0 en UNIT_PRICE
# 4. ✓ Convertir INVOICE_DATE a formato datetime para análisis temporal
# 5. ✓ Considerar crear variable de 'Monto Total' = QUANTITY * UNIT_PRICE
# 6. * Tratar 1,454 descripciones faltantes en DESCRIPTION
# ================================================================================

# %% [markdown]
# ### El dataset de Online Retail contiene 541,909 transacciones de 4,372 clientes únicos con 4,070 productos distintos en un período de 12 meses. Se identificaron varios problemas de calidad:
#
# ### 25% de transacciones sin Customer ID, lo que limita el análisis de comportamiento individual
# ### Valores negativos en Quantity (9,288 registros) que representan devoluciones
# ### Precios atípicos con algunos productos gratuitos o de valor extremadamente alto
# ### La mayoría de las transacciones provienen del Reino Unido, seguido de Alemania y Francia. La distribución temporal muestra patrones estacionales con picos en ciertos meses.

# %%
# Este mapa de calor nos dara una vista rapida de los valores nulos en el dataset
plt.figure(figsize=(12, 8))
sns.heatmap(data.isnull(), cbar=True, yticklabels=False, cmap='viridis')
plt.title('Mapa de Calor de Valores Nulos', fontsize=14, fontweight='bold')
plt.xlabel('Columnas', fontsize=12)
plt.ylabel('Registros', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# aremos una copia de los datos para procesamiento y limpieza de los mismos

data_proce = data.copy()
data_proce
# Out:
#        INVOICE_NO STOCK_CODE                          DESCRIPTION  QUANTITY  \
# 0          536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365      71053                  WHITE METAL LANTERN         6
# 2          536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...        ...                                  ...       ...
# 541904     581587      22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587      22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             INVOICE_DATE  UNIT_PRICE  CUSTOMER_ID          REGION
# 0       01/12/2019 08:26        2.55      17850.0  United Kingdom
# 1       01/12/2019 08:26        3.39      17850.0  United Kingdom
# 2       01/12/2019 08:26        2.75      17850.0  United Kingdom
# 3       01/12/2019 08:26        3.39      17850.0  United Kingdom
# 4       01/12/2019 08:26        3.39      17850.0  United Kingdom
# ...                  ...         ...          ...             ...
# 541904  09/12/2020 12:50        0.85      12680.0          France
# 541905  09/12/2020 12:50        2.10      12680.0          France
# 541906  09/12/2020 12:50        4.15      12680.0          France
# 541907  09/12/2020 12:50        4.15      12680.0          France
# 541908  09/12/2020 12:50        4.95      12680.0          France
#
# [541909 rows x 8 columns]

# %%
# filtrar filas basadas en la columna 'CUSTOMER_ID' por vacias
data_vacias = data_proce[data_proce['CUSTOMER_ID'].isnull()]
data_vacias
# Out:
#        INVOICE_NO STOCK_CODE                      DESCRIPTION  QUANTITY  \
# 622        536414      22139                              NaN        56
# 1443       536544      21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444       536544      21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445       536544      21786               POLKADOT RAIN HAT          4
# 1446       536544      21787            RAIN PONCHO RETROSPOT         2
# ...           ...        ...                              ...       ...
# 541536     581498     85099B          JUMBO BAG RED RETROSPOT         5
# 541537     581498     85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538     581498      85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539     581498      85174                S/4 CACTI CANDLES         1
# 541540     581498        DOT                   DOTCOM POSTAGE         1
#
#             INVOICE_DATE  UNIT_PRICE  CUSTOMER_ID          REGION
# 622     01/12/2019 11:52        0.00          NaN  United Kingdom
# 1443    01/12/2019 14:32        2.51          NaN  United Kingdom
# 1444    01/12/2019 14:32        2.51          NaN  United Kingdom
# 1445    01/12/2019 14:32        0.85          NaN  United Kingdom
# 1446    01/12/2019 14:32        1.66          NaN  United Kingdom
# ...                  ...         ...          ...             ...
# 541536  09/12/2020 10:26        4.13          NaN  United Kingdom
# 541537  09/12/2020 10:26        4.13          NaN  United Kingdom
# 541538  09/12/2020 10:26        4.96          NaN  United Kingdom
# 541539  09/12/2020 10:26       10.79          NaN  United Kingdom
# 541540  09/12/2020 10:26     1714.17          NaN  United Kingdom
#
# [135080 rows x 8 columns]

# %%
print("{0:,} valores nulos en CUSTOMER_ID ({1:.1f}%)".format(
    data['CUSTOMER_ID'].isnull().sum(), 
    data['CUSTOMER_ID'].isnull().sum()/len(data)*100))
# Out:
# 135,080 valores nulos en CUSTOMER_ID (24.9%)

# %%
# Eliminar las filas vacias de 'CUSTOMER_ID' a nuestra dataproce
data_proce.drop(data_vacias.index, inplace =True)
data_proce
# Out:
#        INVOICE_NO STOCK_CODE                          DESCRIPTION  QUANTITY  \
# 0          536365     85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365      71053                  WHITE METAL LANTERN         6
# 2          536365     84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365     84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365     84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...        ...                                  ...       ...
# 541904     581587      22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587      22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587      23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587      23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587      22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             INVOICE_DATE  UNIT_PRICE  CUSTOMER_ID          REGION
# 0       01/12/2019 08:26        2.55      17850.0  United Kingdom
# 1       01/12/2019 08:26        3.39      17850.0  United Kingdom
# 2       01/12/2019 08:26        2.75      17850.0  United Kingdom
# 3       01/12/2019 08:26        3.39      17850.0  United Kingdom
# 4       01/12/2019 08:26        3.39      17850.0  United Kingdom
# ...                  ...         ...          ...             ...
# 541904  09/12/2020 12:50        0.85      12680.0          France
# 541905  09/12/2020 12:50        2.10      12680.0          France
# 541906  09/12/2020 12:50        4.15      12680.0          France
# 541907  09/12/2020 12:50        4.15      12680.0          France
# 541908  09/12/2020 12:50        4.95      12680.0          France
#
# [406829 rows x 8 columns]

# %%
# Mostramos el mapa de calor de los valores nulos en el dataset procesado
plt.figure(figsize=(12, 8))
sns.heatmap(data_proce.isnull(), cbar=True, yticklabels=False, cmap='viridis')
plt.title('Mapa de Calor de Valores Nulos en el Dataset', fontsize=14, fontweight='bold')
plt.xlabel('Columnas', fontsize=12)
plt.ylabel('Registros', fontsize=12)
plt.tight_layout()
plt.show()

# %%
# Analizar los negativos en 'QUANTITY'

def clean_data(data_proce):
    # Filtrar negativos de: 'QUANTITY'
    data_proce = data_proce[data_proce['QUANTITY'].apply(str).str.contains("-", regex=False, na=False, case=False)]
    return data_proce

data_proce_negativos = clean_data(data_proce.copy())
data_proce_negativos.info()
print('=' * 40)
print(data_proce_negativos.describe())
print('=' * 40)
data_proce_negativos['QUANTITY'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8905 entries, 141 to 541717
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   INVOICE_NO    8905 non-null   object
#  1   STOCK_CODE    8905 non-null   object
#  2   DESCRIPTION   8905 non-null   object
#  3   QUANTITY      8905 non-null   int64
#  4   INVOICE_DATE  8905 non-null   object
#  5   UNIT_PRICE    8905 non-null   float64
#  6   CUSTOMER_ID   8905 non-null   float64
#  7   REGION        8905 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 626.1+ KB
# ========================================
#            QUANTITY    UNIT_PRICE   CUSTOMER_ID
# count   8905.000000   8905.000000   8905.000000
# mean     -30.859966     18.845519  14991.667266
# std     1170.154939    444.366043   1706.772357
# min   -80995.000000      0.010000  12346.000000
# 25%       -6.000000      1.450000  13510.000000
# 50%       -2.000000      2.950000  14895.000000
# 75%       -1.000000      4.950000  16393.000000
# max       -1.000000  38970.000000  18282.000000
# ========================================
# QUANTITY
# -1        3848
# -2        1329
# -3         577
# -12        520
# -6         468
#           ...
# -184         1
# -244         1
# -234         1
# -132         1
# -80995       1
# Name: count, Length: 134, dtype: int64

# %%
# Contar el total de negativos en 'QUANTITY'
data_proce_negativos_suma = data_proce_negativos['QUANTITY'].sum()
data_proce_negativos_suma
# Out:
# np.int64(-274808)

# %%
# multilica los valores negativos por el numero de veces que se repiten para sacar el total de negativos
negativo = 0
for index, row in data_proce_negativos['QUANTITY'].value_counts().items():
    negativo += int(index) * row
negativo
# Out:
# -274808

# %% [markdown]
# # Recency
# <p>Indicador que nos dice que tan reciente es la compra de un cliente</p>

# %%
# Obtener los clientes unicos
customer = data_proce['CUSTOMER_ID'].unique()
customer
# Out:
# array([17850., 13047., 12583., ..., 13298., 14569., 12713.], shape=(4372,))

# %%
# Obtener la última fecha de compra por cliente
max_purchase = data_proce.groupby('CUSTOMER_ID')['INVOICE_DATE'].max()
max_purchase
# Out:
# CUSTOMER_ID
# 12346.0    18/01/2020 10:17
# 12347.0    31/10/2020 12:25
# 12348.0    25/09/2020 13:13
# 12349.0    21/11/2020 09:51
# 12350.0    02/02/2020 16:01
#                  ...
# 18280.0    07/03/2020 09:52
# 18281.0    12/06/2020 10:53
# 18282.0    09/08/2020 15:10
# 18283.0    30/11/2020 12:59
# 18287.0    28/10/2020 09:29
# Name: INVOICE_DATE, Length: 4372, dtype: object

# %%
# Vamos a calcular nuestra metrica de Recency, esto lo haremos restando los días de la última fecha de compra a cada observación

# Convertir INVOICE_DATE a datetime en el dataset original
data_proce['INVOICE_DATE'] = pd.to_datetime(data_proce['INVOICE_DATE'], format='%d/%m/%Y %H:%M', errors='coerce')

# calcular
max_purchase = data_proce.groupby('CUSTOMER_ID')['INVOICE_DATE'].max()
fecha_referencia = data_proce['INVOICE_DATE'].max()
recency = (fecha_referencia - max_purchase).dt.days

# Crear DataFrame
max_purchase = pd.DataFrame({
    'INVOICE_DATE': max_purchase,
    'RECENCY': recency
}).sort_values('RECENCY', ascending=False)

max_purchase
# Out:
#                    INVOICE_DATE  RECENCY
# CUSTOMER_ID
# 13747.0     2019-12-01 10:37:00      374
# 12791.0     2019-12-01 11:27:00      374
# 16583.0     2019-12-01 12:03:00      374
# 14729.0     2019-12-01 12:43:00      374
# 18074.0     2019-12-01 09:53:00      374
# ...                         ...      ...
# 17405.0     2020-12-08 17:12:00        0
# 17389.0     2020-12-09 09:38:00        0
# 12526.0     2020-12-09 12:09:00        0
# 12518.0     2020-12-09 10:13:00        0
# 16401.0     2020-12-08 18:15:00        0
#
# [4372 rows x 2 columns]

# %%
# Unir el DataFrame de clientes únicos con el que acabamos de crear de la última fecha de compra
customer_recency = pd.DataFrame({'CUSTOMER_ID': customer}).merge(
    max_purchase,
    on='CUSTOMER_ID',
    how='left'
)  
customer_recency
# Out:
#       CUSTOMER_ID        INVOICE_DATE  RECENCY
# 0         17850.0 2020-02-10 14:38:00      302
# 1         13047.0 2020-11-08 12:10:00       31
# 2         12583.0 2020-12-07 08:07:00        2
# 3         13748.0 2020-09-05 09:45:00       95
# 4         15100.0 2020-01-13 17:09:00      330
# ...           ...                 ...      ...
# 4367      13436.0 2020-12-08 10:33:00        1
# 4368      15520.0 2020-12-08 10:58:00        1
# 4369      13298.0 2020-12-08 13:11:00        0
# 4370      14569.0 2020-12-08 14:58:00        0
# 4371      12713.0 2020-12-09 12:16:00        0
#
# [4372 rows x 3 columns]

# %%
# Grafica un histograma de Recency
plt.figure(figsize=(10,6))
sns.histplot(customer_recency['RECENCY'], bins=30, kde=True)
plt.show()

# %%
# Imprime la Estadística de Resumen para Recency
customer_recency['RECENCY'].describe()
# Out:
# count    4372.000000
# mean       91.123056
# std       100.946554
# min         0.000000
# 25%        16.000000
# 50%        49.000000
# 75%       142.000000
# max       374.000000
# Name: RECENCY, dtype: float64

# %% [markdown]
# ### Los clientes muestran una alta variabilidad en su última fecha de compra
# ### La mayoría tiene valores de recency altos (>300 días), indicando que muchos clientes no han regresado recientemente
# ### Media: ~93 días, Mediana: 42 días

# %% [markdown]
# ## Frequency
# <p>Frecuencia con la que un cliente compra uno o más productos</p>

# %%
# Obtener el número de compras por cliente
frequency = data_proce.groupby('CUSTOMER_ID').size().rename('FREQUENCY')
frequency
# Out:
# CUSTOMER_ID
# 12346.0      2
# 12347.0    182
# 12348.0     31
# 12349.0     73
# 12350.0     17
#           ...
# 18280.0     10
# 18281.0      7
# 18282.0     13
# 18283.0    756
# 18287.0     70
# Name: FREQUENCY, Length: 4372, dtype: int64

# %%
# Unir el DataFrame que acabamos de crear con el de los clientes unicos
customer = max_purchase.reset_index()
customer = customer.merge(frequency.rename('FREQUENCY'), on='CUSTOMER_ID', how='left')
customer
# Out:
#       CUSTOMER_ID        INVOICE_DATE  RECENCY  FREQUENCY
# 0         13747.0 2019-12-01 10:37:00      374          1
# 1         12791.0 2019-12-01 11:27:00      374          2
# 2         16583.0 2019-12-01 12:03:00      374         14
# 3         14729.0 2019-12-01 12:43:00      374         71
# 4         18074.0 2019-12-01 09:53:00      374         13
# ...           ...                 ...      ...        ...
# 4367      17405.0 2020-12-08 17:12:00        0         94
# 4368      17389.0 2020-12-09 09:38:00        0        224
# 4369      12526.0 2020-12-09 12:09:00        0         71
# 4370      12518.0 2020-12-09 10:13:00        0        124
# 4371      16401.0 2020-12-08 18:15:00        0        198
#
# [4372 rows x 4 columns]

# %%
# Grafica un histograma de Frequency
# Filtrar outliers para mejor visualización
frequency_limit = customer['FREQUENCY'].quantile(0.95)  # 95 percentil

plt.figure(figsize=(12, 6))
plt.hist(customer[customer['FREQUENCY'] <= frequency_limit]['FREQUENCY'], 
         bins=50, edgecolor='black', color='skyblue')
plt.xlabel('Frecuencia de Compra', fontsize=12)
plt.ylabel('Número de Clientes', fontsize=12)
plt.title('Distribución de Frecuencia de Compras por Cliente (sin outliers)', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.axvline(customer['FREQUENCY'].mean(), color='red', linestyle='--', 
            label=f'Media: {customer["FREQUENCY"].mean():.2f}')
plt.axvline(customer['FREQUENCY'].median(), color='green', linestyle='--', 
            label=f'Mediana: {customer["FREQUENCY"].median():.2f}')
plt.legend()
plt.show()

# %%
# Imprime la Estadística de Resumen para Frequency
print(f"\nEstadísticas de FREQUENCY:")
print(customer['FREQUENCY'].describe())
print(f"\nClientes con más de 1000 compras: {(customer['FREQUENCY'] > 1000).sum()}")
# Out:
# Estadísticas de FREQUENCY:
# count    4372.000000
# mean       93.053294
# std       232.471608
# min         1.000000
# 25%        17.000000
# 50%        42.000000
# 75%       102.000000
# max      7983.000000
# Name: FREQUENCY, dtype: float64
#
# Clientes con más de 1000 compras: 22

# %% [markdown]
# ### Distribución altamente sesgada con la mayoría de clientes realizando pocas compras
# ### Media: 93 transacciones, Mediana: 42 transacciones
# ### Pocos clientes "power users" con más de 1,000 transacciones

# %% [markdown]
# ## Monetary
# <p>Valor del monto total que ha gastado un cliente en la compra de mis productos</p>

# %%
# Calcular el monto total por cada compra
data_proce['MONETARY'] = data_proce['QUANTITY'] * data_proce['UNIT_PRICE']

# Obtener el valor monetario de compra por cliente
monetary = data_proce.groupby('CUSTOMER_ID')['MONETARY'].sum()
monetary
# Out:
# CUSTOMER_ID
# 12346.0       0.00
# 12347.0    4310.00
# 12348.0    1797.24
# 12349.0    1757.55
# 12350.0     334.40
#             ...
# 18280.0     180.60
# 18281.0      80.82
# 18282.0     176.60
# 18283.0    2094.88
# 18287.0    1837.28
# Name: MONETARY, Length: 4372, dtype: float64

# %%
# Unir el DataFrame que acabamos de crear con el de los clientes unicos
customer = customer.merge(monetary.rename('MONETARY'), on='CUSTOMER_ID', how='left')
customer
# Out:
#       CUSTOMER_ID        INVOICE_DATE  RECENCY  FREQUENCY  MONETARY
# 0         13747.0 2019-12-01 10:37:00      374          1     79.60
# 1         12791.0 2019-12-01 11:27:00      374          2    192.60
# 2         16583.0 2019-12-01 12:03:00      374         14    233.45
# 3         14729.0 2019-12-01 12:43:00      374         71    313.49
# 4         18074.0 2019-12-01 09:53:00      374         13    489.60
# ...           ...                 ...      ...        ...       ...
# 4367      17405.0 2020-12-08 17:12:00        0         94    967.22
# 4368      17389.0 2020-12-09 09:38:00        0        224  31300.08
# 4369      12526.0 2020-12-09 12:09:00        0         71   1316.66
# 4370      12518.0 2020-12-09 10:13:00        0        124   2056.89
# 4371      16401.0 2020-12-08 18:15:00        0        198   4061.24
#
# [4372 rows x 5 columns]

# %%
# Grafica un histograma de Monetary
# Filtrar outliers para mejor visualización
monetary_limit = customer['MONETARY'].quantile(0.95)  # 95 percentil

plt.figure(figsize=(12, 6))
plt.hist(customer[customer['MONETARY'] <= monetary_limit]['MONETARY'], 
         bins=50, edgecolor='black', color='lightgreen')
plt.xlabel('Valor Monetario ($)', fontsize=12)
plt.ylabel('Número de Clientes', fontsize=12)
plt.title('Distribución del Valor Monetario por Cliente (sin outliers)', fontsize=14, fontweight='bold')
plt.grid(True, alpha=0.3)
plt.axvline(customer['MONETARY'].mean(), color='red', linestyle='--', 
            label=f'Media: ${customer["MONETARY"].mean():.2f}')
plt.axvline(customer['MONETARY'].median(), color='blue', linestyle='--', 
            label=f'Mediana: ${customer["MONETARY"].median():.2f}')
plt.legend()
plt.show()

# %%
# Imprime la Estadística de Resumen para Monetary
# Mostrar estadísticas
print(f"\nEstadísticas de MONETARY:")
print(customer['MONETARY'].describe())
print(f"\nClientes con gasto > $50,000: {(customer['MONETARY'] > 50000).sum()}")
print(f"Clientes con gasto > $100,000: {(customer['MONETARY'] > 100000).sum()}")
# Out:
# Estadísticas de MONETARY:
# count      4372.000000
# mean       1898.459701
# std        8219.345141
# min       -4287.630000
# 25%         293.362500
# 50%         648.075000
# 75%        1611.725000
# max      279489.020000
# Name: MONETARY, dtype: float64
#
# Clientes con gasto > $50,000: 18
# Clientes con gasto > $100,000: 6

# %%
customer
# Out:
#       CUSTOMER_ID        INVOICE_DATE  RECENCY  FREQUENCY  MONETARY
# 0         13747.0 2019-12-01 10:37:00      374          1     79.60
# 1         12791.0 2019-12-01 11:27:00      374          2    192.60
# 2         16583.0 2019-12-01 12:03:00      374         14    233.45
# 3         14729.0 2019-12-01 12:43:00      374         71    313.49
# 4         18074.0 2019-12-01 09:53:00      374         13    489.60
# ...           ...                 ...      ...        ...       ...
# 4367      17405.0 2020-12-08 17:12:00        0         94    967.22
# 4368      17389.0 2020-12-09 09:38:00        0        224  31300.08
# 4369      12526.0 2020-12-09 12:09:00        0         71   1316.66
# 4370      12518.0 2020-12-09 10:13:00        0        124   2056.89
# 4371      16401.0 2020-12-08 18:15:00        0        198   4061.24
#
# [4372 rows x 5 columns]

# %% [markdown]
# # Análisis de Devolucion por cliente

# %%
# Calculamos la taza de devolucion por cliente

# Identificar devoluciones
data_proce['DEVOLUCION'] = data_proce['QUANTITY'] < 0

# Calcular tasa de devolución por cliente
tasa_devolucion = data_proce.groupby('CUSTOMER_ID')['DEVOLUCION'].mean()
tasa_devolucion.sort_values(ascending=False)
# Out:
# CUSTOMER_ID
# 18256.0    1.0
# 16579.0    1.0
# 12505.0    1.0
# 14679.0    1.0
# 14213.0    1.0
#           ...
# 18222.0    0.0
# 12407.0    0.0
# 12405.0    0.0
# 12402.0    0.0
# 12401.0    0.0
# Name: DEVOLUCION, Length: 4372, dtype: float64

# %%
print(f"Clientes que solo devuelven (100% devoluciones): {(tasa_devolucion == 1.0).sum()}")
print(f"Clientes con alguna devolución: {(tasa_devolucion > 0).sum()}")
print(f"Clientes sin devoluciones: {(tasa_devolucion == 0).sum()}")
print(f"Promedio de devoluciones por cliente: {tasa_devolucion.mean():.4f}")
# Out:
# Clientes que solo devuelven (100% devoluciones): 33
# Clientes con alguna devolución: 1589
# Clientes sin devoluciones: 2783
# Promedio de devoluciones por cliente: 0.0320

# %%
# Unir el DataFrame con la taza de devolicion por cliente
customer = customer.merge(tasa_devolucion.rename('DEVOLUCION'), on='CUSTOMER_ID', how='left')
customer
# Out:
#       CUSTOMER_ID        INVOICE_DATE  RECENCY  FREQUENCY  MONETARY  \
# 0         13747.0 2019-12-01 10:37:00      374          1     79.60
# 1         12791.0 2019-12-01 11:27:00      374          2    192.60
# 2         16583.0 2019-12-01 12:03:00      374         14    233.45
# 3         14729.0 2019-12-01 12:43:00      374         71    313.49
# 4         18074.0 2019-12-01 09:53:00      374         13    489.60
# ...           ...                 ...      ...        ...       ...
# 4367      17405.0 2020-12-08 17:12:00        0         94    967.22
# 4368      17389.0 2020-12-09 09:38:00        0        224  31300.08
# 4369      12526.0 2020-12-09 12:09:00        0         71   1316.66
# 4370      12518.0 2020-12-09 10:13:00        0        124   2056.89
# 4371      16401.0 2020-12-08 18:15:00        0        198   4061.24
#
#       DEVOLUCION
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# ...          ...
# 4367    0.127660
# 4368    0.049107
# 4369    0.000000
# 4370    0.000000
# 4371    0.060606
#
# [4372 rows x 6 columns]

# %%
# Vamos a eliminar los que den el 100% de devoluciones ya que estos no aportan valor al análisis debido a que no generan ingresos reales para la empresa y distorcionan los resultados
# Tambien rompen el modelo RFM 
# El algoritmo Kmeans no puede manejar bien estos datos ya que son muy extremos
# Solo son '33' usuarios con el 100% de devoluciones
print(f"Conteo de clientes con el 100% de devoluciones : {(tasa_devolucion == 1.0).sum()}")
print('33 clientes con el 100% de devoluciones, se eliminaran del analisis.')
print('PROCESANDO...')
customer = customer[customer['DEVOLUCION'] < 1.0]
customer
# Out:
# Conteo de clientes con el 100% de devoluciones : 33
# 33 clientes con el 100% de devoluciones, se eliminaran del analisis.
# PROCESANDO...
#       CUSTOMER_ID        INVOICE_DATE  RECENCY  FREQUENCY  MONETARY  \
# 0         13747.0 2019-12-01 10:37:00      374          1     79.60
# 1         12791.0 2019-12-01 11:27:00      374          2    192.60
# 2         16583.0 2019-12-01 12:03:00      374         14    233.45
# 3         14729.0 2019-12-01 12:43:00      374         71    313.49
# 4         18074.0 2019-12-01 09:53:00      374         13    489.60
# ...           ...                 ...      ...        ...       ...
# 4367      17405.0 2020-12-08 17:12:00        0         94    967.22
# 4368      17389.0 2020-12-09 09:38:00        0        224  31300.08
# 4369      12526.0 2020-12-09 12:09:00        0         71   1316.66
# 4370      12518.0 2020-12-09 10:13:00        0        124   2056.89
# 4371      16401.0 2020-12-08 18:15:00        0        198   4061.24
#
#       DEVOLUCION
# 0       0.000000
# 1       0.000000
# 2       0.000000
# 3       0.000000
# 4       0.000000
# ...          ...
# 4367    0.127660
# 4368    0.049107
# 4369    0.000000
# 4370    0.000000
# 4371    0.060606
#
# [4339 rows x 6 columns]

# %%
# ESTADISTICAS FINALES DEL DATAFRAME CUSTOMER
print(customer.describe())
print('='*50)
print('MEAN DE CADA COLUMNA:')
print(customer.mean())
print('='*50)
print('Contador de valores unicos en MONETARY:')
print(customer['MONETARY'].value_counts())
print('='*50)
print('Contador de valores unicos de FREQUENCY:')
print(customer['FREQUENCY'].value_counts())
print('='*50)
print('Contador de valores unicos de RECENCY:')
print(customer['RECENCY'].value_counts())
print('='*50)
print('Contador de valores unicos de DEVOLUCION:')
print(customer['DEVOLUCION'].value_counts())
# Out:
#         CUSTOMER_ID                   INVOICE_DATE      RECENCY    FREQUENCY  \
# count   4339.000000                           4339  4339.000000  4339.000000
# mean   15299.936852  2020-09-10 09:30:12.002765312    89.619267    93.740724
# min    12346.000000            2019-12-01 09:53:00     0.000000     1.000000
# 25%    13812.500000            2020-07-24 12:32:00    16.000000    18.000000
# 50%    15299.000000            2020-10-21 11:06:00    49.000000    42.000000
# 75%    16778.500000            2020-11-23 11:12:30   138.000000   102.000000
# max    18287.000000            2020-12-09 12:50:00   374.000000  7983.000000
# std     1721.889758                            NaN    99.397784   233.219740
#
#             MONETARY   DEVOLUCION
# count    4339.000000  4339.000000
# mean     1915.297777     0.024683
# min     -1165.300000     0.000000
# 25%       299.675000     0.000000
# 50%       654.920000     0.000000
# 75%      1623.825000     0.019901
# max    279489.020000     0.941176
# std      8247.979285     0.065993
# ==================================================
# MEAN DE CADA COLUMNA:
# CUSTOMER_ID                      15299.936852
# INVOICE_DATE    2020-09-10 09:30:12.002765312
# RECENCY                             89.619267
# FREQUENCY                           93.740724
# MONETARY                          1915.297777
# DEVOLUCION                           0.024683
# dtype: object
# ==================================================
# Contador de valores unicos en MONETARY:
# MONETARY
# 0.00        8
# 76.32       4
# 440.00      3
# 363.65      3
# 35.40       3
#            ..
# 967.22      1
# 31300.08    1
# 1316.66     1
# 2056.89     1
# 1926.88     1
# Name: count, Length: 4255, dtype: int64
# ==================================================
# Contador de valores unicos de FREQUENCY:
# FREQUENCY
# 6       78
# 10      74
# 12      72
# 7       72
# 11      70
#         ..
# 1165     1
# 1128     1
# 407      1
# 2782     1
# 293      1
# Name: count, Length: 474, dtype: int64
# ==================================================
# Contador de valores unicos de RECENCY:
# RECENCY
# 3      126
# 0      105
# 8      105
# 2      100
# 1       92
#       ...
# 82       1
# 209      1
# 243      1
# 314      1
# 258      1
# Name: count, Length: 350, dtype: int64
# ==================================================
# Contador de valores unicos de DEVOLUCION:
# DEVOLUCION
# 0.000000    2783
# 0.166667      21
# 0.500000      21
# 0.111111      19
# 0.038462      17
#             ...
# 0.263158       1
# 0.941176       1
# 0.312500       1
# 0.068750       1
# 0.029536       1
# Name: count, Length: 776, dtype: int64

# %% [markdown]
# ### Fuerte correlación con Frequency: clientes frecuentes gastan más
# ### Distribución sesgada con muchos clientes de bajo valor y pocos de alto valor
# ### Presencia de outliers significativos (clientes que gastan >$50,000)

# %% [markdown]
# ## Algoritmo k-Means
# <p>Ya creamos nuestros indicadores principales de la metodología RFM. es hora de hacer <i>Machine Learning</i>. Para ello utilizaremos un algoritmo no supervisado llamado <b>k-Means</b></p>
# <p><img src="https://miro.medium.com/max/818/1*fG8u8nV7qR91wDyFDEEV-g.png" width="250"/></p>

# %%
# Funcion para ordenar los clusters
def order_cluster(cluster_field_name, target_field_name, df, ascending):
    new_cluster_field_name = 'new_' + cluster_field_name
    df_new = df.groupby(cluster_field_name)[target_field_name].mean().reset_index()
    df_new = df_new.sort_values(by=target_field_name,ascending=ascending).reset_index(drop=True)
    df_new['index'] = df_new.index
    df_final = pd.merge(df,df_new[[cluster_field_name,'index']], on=cluster_field_name)
    df_final = df_final.drop([cluster_field_name],axis=1)
    df_final = df_final.rename(columns={"index":cluster_field_name})
    return df_final

# %% [markdown]
# ## Elbow Method
# <p>¿Cual es mi número óptimo de clusters? Vamos a contruir una <i>gráfica de codo</i> para averiguarlo</p>

# %%
# Importa la librería de kMeans
from sklearn.cluster import KMeans

# %%
# Configuración inicial - Vamos a tomar como referencia el indicador de Recency
sse={}
recency = customer[['RECENCY']]

for k in range(1, 10):
    # Instancia el algoritmo de k-means iterando sobre k
    kmeans = KMeans(n_clusters=k, random_state=42)
    
    # Entrena el algoritmo
    kmeans.fit(recency)
    
    # Adjunta las etiquetas
    recency["clusters"] = kmeans.labels_
    
    # Adunta la inercia o variación al arreglo sse
    sse[k] = kmeans.inertia_
    
# Grafico de codo (Elbow)
plt.figure(figsize=(12,8))
plt.plot(list(sse.keys()), list(sse.values()))
plt.xlabel("Number of cluster")
plt.show()
# Out:
# C:\Users\randy\AppData\Local\Temp\ipykernel_10536\3840669696.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recency["clusters"] = kmeans.labels_
# C:\Users\randy\AppData\Local\Temp\ipykernel_10536\3840669696.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recency["clusters"] = kmeans.labels_
# C:\Users\randy\AppData\Local\Temp\ipykernel_10536\3840669696.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recency["clusters"] = kmeans.labels_
# C:\Users\randy\AppData\Local\Temp\ipykernel_10536\3840669696.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recency["clusters"] = kmeans.labels_
# C:\Users\randy\AppData\Local\Temp\ipykernel_10536\3840669696.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recency["clusters"] = kmeans.labels_
# C:\Users\randy\AppData\Local\Temp\ipykernel_10536\3840669696.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recency["clusters"] = kmeans.labels_
# C:\Users\randy\AppData\Local\Temp\ipykernel_10536\3840669696.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recency["clusters"] = kmeans.labels_
# C:\Users\randy\AppData\Local\Temp\ipykernel_10536\3840669696.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recency["clusters"] = kmeans.labels_
# C:\Users\randy\AppData\Local\Temp\ipykernel_10536\3840669696.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   recency["clusters"] = kmeans.labels_

# %%
# Instanciar el algoritmo con 4 clusters para Recency 
kmeans = KMeans(n_clusters=4, random_state=42)

# Entrenar el algoritmo
kmeans.fit(recency) 

# Obtener las predicciones
customer['RECENCY_CLUSTER'] = kmeans.labels_

# Ordenar los clusters
customer = order_cluster('RECENCY_CLUSTER', 'RECENCY', customer, False)

# Estadística Descriptiva del cluster creado
customer.groupby('RECENCY_CLUSTER')['RECENCY'].describe()
# Out:
#                   count        mean        std    min     25%    50%    75%  \
# RECENCY_CLUSTER
# 0                 481.0  307.634096  39.018094  250.0  273.00  304.0  336.0
# 1                 600.0  191.698333  31.818255  139.0  164.75  189.0  217.0
# 2                 961.0   84.560874  23.838403   53.0   64.00   78.0  104.0
# 3                2297.0   19.418372  15.013712    0.0    7.00   17.0   30.0
#
#                    max
# RECENCY_CLUSTER
# 0                374.0
# 1                249.0
# 2                138.0
# 3                 52.0

# %%
# Instanciar el algoritmo con 4 clusters para Frequency 
kmeans = KMeans(n_clusters=4, random_state=42)

# Entrenar el algoritmo
kmeans.fit(customer[['FREQUENCY']])

# Obtener las predicciones
customer['FREQUENCY_CLUSTER'] = kmeans.labels_

# Ordenar los clusters
customer = order_cluster('FREQUENCY_CLUSTER', 'FREQUENCY', customer, True)

# Estadística Descriptiva de los clusters
customer.groupby('FREQUENCY_CLUSTER')['FREQUENCY'].describe()
# Out:
#                     count         mean          std     min     25%     50%  \
# FREQUENCY_CLUSTER
# 0                  3829.0    50.159572    44.789842     1.0    16.0    34.0
# 1                   482.0   329.107884   132.670589   190.0   228.0   286.0
# 2                    24.0  1349.750000   508.637759   872.0  1003.5  1156.0
# 3                     4.0  5914.000000  1473.845537  4642.0  5006.5  5515.5
#
#                       75%     max
# FREQUENCY_CLUSTER
# 0                    73.0   189.0
# 1                   393.5   803.0
# 2                  1541.0  2782.0
# 3                  6423.0  7983.0

# %%
# Instanciar el algoritmo con 4 clusters para Monetary 
kmeans = KMeans(n_clusters=4, random_state=42)

# Entrenar el algoritmo
kmeans.fit(customer[['MONETARY']])

# Obtener las predicciones
customer['MONETARY_CLUSTER'] = kmeans.labels_

# Ordenar los clusters ¿Como tienes que ordenar el cluster?
customer = order_cluster('MONETARY_CLUSTER', 'MONETARY', customer, True)

# Estadística Descriptiva de los clusters
customer.groupby('MONETARY_CLUSTER')['MONETARY'].describe()
# Out:
#                    count           mean           std        min          25%  \
# MONETARY_CLUSTER
# 0                 4305.0    1399.345488   2167.659364   -1165.30     297.9500
# 1                   28.0   42614.387143  15826.362501   25748.35   28968.7950
# 2                    4.0  139291.095000  33070.516767  113384.14  121140.1225
# 3                    2.0  267963.755000  16299.186073  256438.49  262201.1225
#
#                          50%          75%        max
# MONETARY_CLUSTER
# 0                    647.740    1578.6700   21535.90
# 1                  35078.555   53120.3150   88125.38
# 2                 128149.035  146300.0075  187482.17
# 3                 267963.755  273726.3875  279489.02

# %% [markdown]
# ## Score de Segmentación
# <p>El algoritmo de k-means nos da una segmentación generalizada, pero podemos personalizarla aún más creando una métrica que asigne una calificación al valor del cluster. Esto es lo que vamos a hacer!!</p>

# %%
# Vamos a crear nuestro score sumando el valor de cada uno de los clusters
customer['SCORE'] = customer['RECENCY_CLUSTER'] + customer['FREQUENCY_CLUSTER'] + customer['MONETARY_CLUSTER']

# Obtener el promedio para cada una de las métricas de las calificaciones creadas (Score)
customer.groupby('SCORE').mean()
# Out:
#         CUSTOMER_ID                  INVOICE_DATE     RECENCY    FREQUENCY  \
# SCORE
# 0      15270.129436 2020-02-05 09:05:22.797494784  307.649269    23.288100
# 1      15435.783557 2020-05-30 15:12:46.208053504  192.380872    33.107383
# 2      15205.660580 2020-09-14 14:23:01.224489728   85.395274    45.730397
# 3      15301.951075 2020-11-16 15:24:44.709677312   22.370968    69.570968
# 4      15355.778555 2020-11-26 08:31:01.818181632   12.696970   329.177156
# 5      15230.800000 2020-12-01 12:36:08.000000000    7.500000   860.400000
# 6      14736.428571 2020-12-03 19:20:17.142857216    5.142857  1322.000000
# 7      15388.600000 2020-12-06 17:41:36.000000000    2.600000  3921.200000
# 8      14778.500000 2020-12-08 14:03:00.000000000    0.500000  3994.000000
#
#             MONETARY  DEVOLUCION  RECENCY_CLUSTER  FREQUENCY_CLUSTER  \
# SCORE
# 0         368.806910    0.023304         0.000000           0.000000
# 1         595.673609    0.032304         0.996644           0.003356
# 2         901.930314    0.021697         1.993555           0.006445
# 3        1343.360898    0.024347         2.980645           0.019355
# 4        5325.311632    0.022451         3.000000           0.983683
# 5       21750.226333    0.038427         3.000000           1.566667
# 6       84995.020000    0.046213         3.000000           1.714286
# 7       99271.284000    0.009793         3.000000           2.400000
# 8      206030.820000    0.020342         3.000000           2.500000
#
#        MONETARY_CLUSTER
# SCORE
# 0              0.000000
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4              0.016317
# 5              0.433333
# 6              1.285714
# 7              1.600000
# 8              2.500000

# %%
# Crea una funcion que asigne lo siguiente: 
# Si score <= 1 entonces 'Low-Value', si score >1 y <=4 entonces 'Average', si score >4 y <=6 entonces 'Potential', por último si score >6 entonces 'High-Value'
def segment(score): 
    if score <= 1:
        return 'Low-Value'
    elif score > 1 and score <= 4:
        return 'Average'
    elif score > 4 and score <= 6:
        return 'Potential'
    else:
        return 'High-Value'


# Crear una columna aplicando esta función al campo 'SCORE'
customer['SEGMENT'] = customer['SCORE'].apply(segment)
customer
# Out:
#       CUSTOMER_ID        INVOICE_DATE  RECENCY  FREQUENCY  MONETARY  \
# 0         13747.0 2019-12-01 10:37:00      374          1     79.60
# 1         12791.0 2019-12-01 11:27:00      374          2    192.60
# 2         16583.0 2019-12-01 12:03:00      374         14    233.45
# 3         14729.0 2019-12-01 12:43:00      374         71    313.49
# 4         18074.0 2019-12-01 09:53:00      374         13    489.60
# ...           ...                 ...      ...        ...       ...
# 4334      17405.0 2020-12-08 17:12:00        0         94    967.22
# 4335      17389.0 2020-12-09 09:38:00        0        224  31300.08
# 4336      12526.0 2020-12-09 12:09:00        0         71   1316.66
# 4337      12518.0 2020-12-09 10:13:00        0        124   2056.89
# 4338      16401.0 2020-12-08 18:15:00        0        198   4061.24
#
#       DEVOLUCION  RECENCY_CLUSTER  FREQUENCY_CLUSTER  MONETARY_CLUSTER  SCORE  \
# 0       0.000000                0                  0                 0      0
# 1       0.000000                0                  0                 0      0
# 2       0.000000                0                  0                 0      0
# 3       0.000000                0                  0                 0      0
# 4       0.000000                0                  0                 0      0
# ...          ...              ...                ...               ...    ...
# 4334    0.127660                3                  0                 0      3
# 4335    0.049107                3                  1                 1      5
# 4336    0.000000                3                  0                 0      3
# 4337    0.000000                3                  0                 0      3
# 4338    0.060606                3                  1                 0      4
#
#         SEGMENT
# 0     Low-Value
# 1     Low-Value
# 2     Low-Value
# 3     Low-Value
# 4     Low-Value
# ...         ...
# 4334    Average
# 4335  Potential
# 4336    Average
# 4337    Average
# 4338    Average
#
# [4339 rows x 11 columns]

# %%
# Vamos a dar un vistazo a la tabla final
customer.head()
# Out:
#    CUSTOMER_ID        INVOICE_DATE  RECENCY  FREQUENCY  MONETARY  DEVOLUCION  \
# 0      13747.0 2019-12-01 10:37:00      374          1     79.60         0.0
# 1      12791.0 2019-12-01 11:27:00      374          2    192.60         0.0
# 2      16583.0 2019-12-01 12:03:00      374         14    233.45         0.0
# 3      14729.0 2019-12-01 12:43:00      374         71    313.49         0.0
# 4      18074.0 2019-12-01 09:53:00      374         13    489.60         0.0
#
#    RECENCY_CLUSTER  FREQUENCY_CLUSTER  MONETARY_CLUSTER  SCORE    SEGMENT
# 0                0                  0                 0      0  Low-Value
# 1                0                  0                 0      0  Low-Value
# 2                0                  0                 0      0  Low-Value
# 3                0                  0                 0      0  Low-Value
# 4                0                  0                 0      0  Low-Value

# %% [markdown]
# ### Al crear un score RFM combinado (R + F + M) y clasificar a los clientes en 4 segmentos, se obtuvieron los siguientes grupos:
# ### Low-Value (Score ≤ 1): Clientes con poca actividad, compras esporádicas y bajo gasto. Representan el grupo con mayor riesgo de pérdida.
# ### Average (1 < Score ≤ 4): Clientes ocasionales con comportamiento promedio. Tienen potencial de crecimiento con estrategias adecuadas.
# ### Potential (4 < Score ≤ 6): Clientes prometedores que muestran buena actividad en al menos dos dimensiones. Son candidatos ideales para programas de fidelización.
# ### High-Value (Score > 6): Los mejores clientes con alta recurrencia, frecuencia y valor monetario. Requieren atención especial para retención.

# %%
# Imprime la proporción o el total de clientes por segmento
customer['SEGMENT'].value_counts(normalize=True)
# Out:
# SEGMENT
# Average       0.742106
# Low-Value     0.247753
# Potential     0.008527
# High-Value    0.001613
# Name: proportion, dtype: float64

# %%
# Define un estilo 'bmh'
plt.style.use('bmh')

# Filtra los valores para RECENCY < 4000
customer_filtered = customer[customer['RECENCY'] < 4000]

# Crea un grafico de dispersion de 'MONETARY' VS 'RECENCY' por Segmento
plt.figure(figsize=(12, 8))
for segment in customer_filtered['SEGMENT'].unique():
    segment_data = customer_filtered[customer_filtered['SEGMENT'] == segment]
    plt.scatter(segment_data['RECENCY'], segment_data['MONETARY'], 
                label=segment, alpha=0.6, s=50)

plt.xlabel('Recency (días desde última compra)', fontsize=12)
plt.ylabel('Monetary (valor total gastado)', fontsize=12)
plt.title('Dispersión de MONETARY vs RECENCY por Segmento', fontsize=14, fontweight='bold')
plt.legend(title='Segmento')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Los clientes High-Value tienden a tener baja recency (compraron recientemente) y alto valor monetario
# ### Los clientes Low-Value muestran alta recency (no compran hace mucho) y bajo gasto
# ### Clara separación entre segmentos, validando la efectividad del modelo

# %%
# Crea un grafico de dispersion de 'MONETARY' vs 'FREQUENCY' vs  por Segmento
plt.figure(figsize=(12, 8))
for segment in customer_filtered['SEGMENT'].unique():
    segment_data = customer_filtered[customer_filtered['SEGMENT'] == segment]
    plt.scatter(segment_data['FREQUENCY'], segment_data['MONETARY'], 
                label=segment, alpha=0.6, s=50)
plt.xlabel('FREQUENCY (número de compras)', fontsize=12)
plt.ylabel('MONETARY (valor total gastado)', fontsize=12)
plt.title('Dispersión de MONETARY vs FREQUENCY por Segmento', fontsize
=14, fontweight='bold')
plt.legend(title='Segmento')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Relación positiva fuerte: más compras = mayor gasto total
# ### Los clientes High-Value concentrados en alta frecuencia y alto gasto
# ### Algunos clientes Potential con alta frecuencia pero bajo valor unitario (oportunidad de upselling)

# %% [markdown]
# # Recomendaciones Estratégicas
#
# ### Retención de High-Value: Programas VIP, atención personalizada, descuentos exclusivos
# ### Activación de Potential: Campañas de cross-selling y aumentar ticket promedio
# ### Recuperación de Average: Email marketing con ofertas especiales para reactivar compras
# ### Win-back de Low-Value: Campañas agresivas de recuperación o evaluar costo-beneficio de retenerlos
#
# ### El análisis RFM demostró ser efectivo para segmentar la base de clientes y priorizar recursos de marketing hacia los segmentos más valiosos y con mayor potencial de crecimiento.
